# %%
print("Hello, World!")
# Out:
# Hello World

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\students.csv")
print(df)
df.to_sql("students", con=engine, if_exists="replace", index=False)
# Out:
#     id first_name last_name                         email date_of_birth  \
# 0    1      Alice     Smith      alice.smith1@example.edu    2000-01-15
# 1    2   Benjamin       Lee     benjamin.lee2@example.edu    1999-03-22
# 2    3      Chloe   Johnson    chloe.johnson3@example.edu    2001-05-08
# 3    4     Daniel  Martinez  daniel.martinez4@example.edu    2000-07-19
# 4    5       Emma     Brown       emma.brown5@example.edu    2002-09-02
# ..  ..        ...       ...                           ...           ...
# 94  95      Grace    Wilson    grace.wilson95@example.edu    2001-02-14
# 95  96      Henry    Taylor    henry.taylor96@example.edu    1999-04-30
# 96  97       Isla  Anderson   isla.anderson97@example.edu    2002-06-11
# 97  98       Jack    Thomas     jack.thomas98@example.edu    2001-08-23
# 98  99       Kara     White      kara.white99@example.edu    2000-10-05
#
#     grade             major  enrollment_year     status
# 0      92           Biology             2016  graduated
# 1      88  Computer Science             2016  graduated
# 2      95       Mathematics             2016  graduated
# 3      84       Engineering             2016  graduated
# 4      91        Psychology             2016  graduated
# ..    ...               ...              ...        ...
# 94     93        Literature             2024     active
# 95     86           Physics             2024     active
# 96     90         Chemistry             2024     active
# 97     87           History             2024     active
# 98     94               Art             2024     active
#
# [99 rows x 9 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 df = pd.read_csv(r"C:\Users\DELL\Downloads\students.csv")
#       2 print(df)
# ----> 3 df.to_sql("students", con=engine, if_exists="replace", index=False)
#
# NameError: name 'engine' is not defined

# %%
date_of_birth=sorted(df["date_of_birth"])
print(date_of_birth)
# Out:
# ['1998-11-27', '1998-11-27', '1998-11-27', '1998-11-27', '1998-11-27', '1998-11-27', '1998-11-27', '1998-11-27', '1998-11-27', '1999-03-22', '1999-03-22', '1999-03-22', '1999-03-22', '1999-03-22', '1999-03-22', '1999-03-22', '1999-03-22', '1999-03-22', '1999-04-30', '1999-04-30', '1999-04-30', '1999-04-30', '1999-04-30', '1999-04-30', '1999-04-30', '1999-04-30', '1999-04-30', '2000-01-15', '2000-01-15', '2000-01-15', '2000-01-15', '2000-01-15', '2000-01-15', '2000-01-15', '2000-01-15', '2000-01-15', '2000-07-19', '2000-07-19', '2000-07-19', '2000-07-19', '2000-07-19', '2000-07-19', '2000-07-19', '2000-07-19', '2000-07-19', '2000-10-05', '2000-10-05', '2000-10-05', '2000-10-05', '2000-10-05', '2000-10-05', '2000-10-05', '2000-10-05', '2000-10-05', '2001-02-14', '2001-02-14', '2001-02-14', '2001-02-14', '2001-02-14', '2001-02-14', '2001-02-14', '2001-02-14', '2001-02-14', '2001-05-08', '2001-05-08', '2001-05-08', '2001-05-08', '2001-05-08', '2001-05-08', '2001-05-08', '2001-05-08', '2001-05-08', '2001-08-23', '2001-08-23', '2001-08-23', '2001-08-23', '2001-08-23', '2001-08-23', '2001-08-23', '2001-08-23', '2001-08-23', '2002-06-11', '2002-06-11', '2002-06-11', '2002-06-11', '2002-06-11', '2002-06-11', '2002-06-11', '2002-06-11', '2002-06-11', '2002-09-02', '2002-09-02', '2002-09-02', '2002-09-02', '2002-09-02', '2002-09-02', '2002-09-02', '2002-09-02', '2002-09-02']

# %%
data = {
    'Book Title': ['The Great Gatsby', 'To Kill a Mockingbird', '1984', 'Pride and Prejudice', 'The Catcher in the Rye'],
    'Author': ['F. Scott Fitzgerald', 'Harper Lee', 'George Orwell', 'Jane Austen', 'J.D. Salinger'],
    'Genre': ['Classic', 'Classic', 'Dystopian', 'Classic', 'Classic'],
    'Price': [10.99, 8.99, 7.99, 11.99, 9.99],
    'Copies Sold': [500, 600, 800, 300, 450]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                Book Title               Author      Genre  Price  Copies Sold
# 0        The Great Gatsby  F. Scott Fitzgerald    Classic  10.99          500
# 1   To Kill a Mockingbird           Harper Lee    Classic   8.99          600
# 2                    1984        George Orwell  Dystopian   7.99          800
# 3     Pride and Prejudice          Jane Austen    Classic  11.99          300
# 4  The Catcher in the Rye        J.D. Salinger    Classic   9.99          450

# %%
df.groupby('Author').sum()
print(df.groupby('Author').sum())
# Out:
#                                  Book Title      Genre  Price  Copies Sold
# Author
# F. Scott Fitzgerald        The Great Gatsby    Classic  10.99          500
# George Orwell                          1984  Dystopian   7.99          800
# Harper Lee            To Kill a Mockingbird    Classic   8.99          600
# J.D. Salinger        The Catcher in the Rye    Classic   9.99          450
# Jane Austen             Pride and Prejudice    Classic  11.99          300
